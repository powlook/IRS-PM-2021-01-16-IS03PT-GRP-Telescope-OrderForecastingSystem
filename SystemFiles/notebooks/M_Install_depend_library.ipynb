# %%
# P_orderproducts_EDA
# !pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 285 kB 10.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/nguyenmt/Documents/NUS-IS-IS/iss-py/bin/python -m pip install --upgrade pip' command.

# %%
# P_Forecast_Top20_LSTM
# !pip install keras
# !pip install tensorflow
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/nguyenmt/Documents/NUS-IS-IS/iss-py/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/nguyenmt/Documents/NUS-IS-IS/iss-py/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install -r "/Users/nguyenmt/Documents/NUS-IS-IS/IRS-MR Machine Reasoning/Projects/ISS_MR_2021_Anxiety_Diagnosis/SystemFiles/backend/requirements.txt"
# Out:
# ...
#   Using cached numpy-1.20.1-cp39-cp39-macosx_10_9_x86_64.whl (16.1 MB)
# ...
#   Using cached absl_py-0.11.0-py3-none-any.whl (127 kB)
# ...
#   Using cached aiofiles-0.6.0-py3-none-any.whl (11 kB)
# ...
#   Using cached alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached alembic-1.5.8-py2.py3-none-any.whl (159 kB)
# ...
#   Using cached AnyQt-0.0.11-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached apriori-1.0.0.tar.gz (1.8 kB)
# ...
#   Using cached apyori-1.1.2.tar.gz (8.6 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached astropy-4.0.2.tar.gz (7.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# ...
#   Using cached backports.os-0.1.1-py3-none-any.whl (5.8 kB)
# ...
#   Using cached baycomp-1.0.2-py3-none-any.whl (17 kB)
# ...
#   Using cached beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
# ...

# %%
# !pip3 freeze
# Out:
# absl-py==0.12.0
# anyio==2.2.0
# appnope==0.1.2
# argon2-cffi==20.1.0
# astunparse==1.6.3
# async-generator==1.10
# attrs==20.3.0
# Babel==2.9.0
# backcall==0.2.0
# bleach==3.3.0
# cachetools==4.2.2
# certifi==2020.12.5
# cffi==1.14.5
# chardet==4.0.0
# cycler==0.10.0
# Cython==0.29.23
# decorator==4.4.2
# defusedxml==0.7.1
# entrypoints==0.3
# flatbuffers==1.12
# gast==0.4.0
# google-auth==1.30.0
# google-auth-oauthlib==0.4.4
# google-pasta==0.2.0
# greenlet==1.0.0
# grpcio==1.34.1
# h5py==3.1.0
# idna==2.10
# implicit==0.4.4
# ipykernel==5.5.0
# ipython==7.21.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# jedi==0.18.0
# Jinja2==2.11.3
# joblib==1.0.1
# json5==0.9.5
# jsonschema==3.2.0
# jupyter-client==6.1.12
# jupyter-core==4.7.1
# jupyter-packaging==0.7.12
# jupyter-server==1.4.1
# jupyterlab==3.0.12
# jupyterlab-pygments==0.1.2
# jupyterlab-server==2.3.0
# jupyterlab-widgets==1.0.0
# Keras==2.4.3
# keras-nightly==2.5.0.dev2021032900
# Keras-Preprocessing==1.1.2
# ...
